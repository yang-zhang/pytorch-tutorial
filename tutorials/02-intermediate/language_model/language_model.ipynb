# %%
# Some part of the code was referenced from below.
# https://github.com/pytorch/examples/tree/master/word_language_model 
import torch
import torch.nn as nn
import numpy as np
from torch.nn.utils import clip_grad_norm
from data_utils import Dictionary, Corpus


# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Hyper-parameters
embed_size = 128
hidden_size = 1024
num_layers = 1
num_epochs = 5
num_samples = 1000     # number of words to be sampled
batch_size = 20
seq_length = 30
learning_rate = 0.002

# Load "Penn Treebank" dataset
corpus = Corpus()
ids = corpus.get_data('data/train.txt', batch_size)
vocab_size = len(corpus.dictionary)
num_batches = ids.size(1) // seq_length


# RNN based language model
class RNNLM(nn.Module):
    def __init__(self, vocab_size, embed_size, hidden_size, num_layers):
        super(RNNLM, self).__init__()
        self.embed = nn.Embedding(vocab_size, embed_size)
        self.lstm = nn.LSTM(embed_size, hidden_size, num_layers, batch_first=True)
        self.linear = nn.Linear(hidden_size, vocab_size)
        
    def forward(self, x, h):
        # Embed word ids to vectors
        x = self.embed(x)
        
        # Forward propagate LSTM
        out, (h, c) = self.lstm(x, h)
        
        # Reshape output to (batch_size*sequence_length, hidden_size)
        out = out.reshape(out.size(0)*out.size(1), out.size(2))
        
        # Decode hidden states of all time steps
        out = self.linear(out)
        return out, (h, c)

model = RNNLM(vocab_size, embed_size, hidden_size, num_layers).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Truncated backpropagation
def detach(states):
    return [state.detach() for state in states] 

# Train the model
for epoch in range(num_epochs):
    # Set initial hidden and cell states
    states = (torch.zeros(num_layers, batch_size, hidden_size).to(device),
              torch.zeros(num_layers, batch_size, hidden_size).to(device))
    
    for i in range(0, ids.size(1) - seq_length, seq_length):
        # Get mini-batch inputs and targets
        inputs = ids[:, i:i+seq_length].to(device)
        targets = ids[:, (i+1):(i+1)+seq_length].to(device)
        
        # Forward pass
        states = detach(states)
        outputs, states = model(inputs, states)
        loss = criterion(outputs, targets.reshape(-1))
        
        # Backward and optimize
        model.zero_grad()
        loss.backward()
        clip_grad_norm(model.parameters(), 0.5)
        optimizer.step()

        step = (i+1) // seq_length
        if step % 100 == 0:
            print ('Epoch [{}/{}], Step[{}/{}], Loss: {:.4f}, Perplexity: {:5.2f}'
                   .format(epoch+1, num_epochs, step, num_batches, loss.item(), np.exp(loss.item())))

# Test the model
with torch.no_grad():
    with open('sample.txt', 'w') as f:
        # Set intial hidden ane cell states
        state = (torch.zeros(num_layers, 1, hidden_size).to(device),
                 torch.zeros(num_layers, 1, hidden_size).to(device))

        # Select one word id randomly
        prob = torch.ones(vocab_size)
        input = torch.multinomial(prob, num_samples=1).unsqueeze(1).to(device)

        for i in range(num_samples):
            # Forward propagate RNN 
            output, state = model(input, state)

            # Sample a word id
            prob = output.exp()
            word_id = torch.multinomial(prob, num_samples=1).item()

            # Fill input with sampled word id for the next time step
            input.fill_(word_id)

            # File write
            word = corpus.dictionary.idx2word[word_id]
            word = '\n' if word == '<eos>' else word + ' '
            f.write(word)

            if (i+1) % 100 == 0:
                print('Sampled [{}/{}] words and save to {}'.format(i+1, num_samples, 'sample.txt'))

# Save the model checkpoints
torch.save(model.state_dict(), 'model.ckpt')
# Out:
# /Users/yang.zhang/anaconda3/envs/pytorch04/lib/python3.6/site-packages/ipykernel_launcher.py:81: UserWarning: torch.nn.utils.clip_grad_norm is now deprecated in favor of torch.nn.utils.clip_grad_norm_.
# Epoch [1/5], Step[0/1549], Loss: 9.2082, Perplexity: 9978.53
# Epoch [1/5], Step[100/1549], Loss: 6.0002, Perplexity: 403.51
# Epoch [1/5], Step[200/1549], Loss: 5.9389, Perplexity: 379.52
# Epoch [1/5], Step[300/1549], Loss: 5.7844, Perplexity: 325.17
# Epoch [1/5], Step[400/1549], Loss: 5.6890, Perplexity: 295.60
# Epoch [1/5], Step[500/1549], Loss: 5.0846, Perplexity: 161.52
# Epoch [1/5], Step[600/1549], Loss: 5.1829, Perplexity: 178.20
# Epoch [1/5], Step[700/1549], Loss: 5.3877, Perplexity: 218.70
# Epoch [1/5], Step[800/1549], Loss: 5.1706, Perplexity: 176.03
# Epoch [1/5], Step[900/1549], Loss: 5.0682, Perplexity: 158.89
# Epoch [1/5], Step[1000/1549], Loss: 5.1430, Perplexity: 171.23
# Epoch [1/5], Step[1100/1549], Loss: 5.3060, Perplexity: 201.55
# Epoch [1/5], Step[1200/1549], Loss: 5.1491, Perplexity: 172.27
# Epoch [1/5], Step[1300/1549], Loss: 5.0860, Perplexity: 161.74
# Epoch [1/5], Step[1400/1549], Loss: 4.8250, Perplexity: 124.59
# Epoch [1/5], Step[1500/1549], Loss: 5.1627, Perplexity: 174.63
# Epoch [2/5], Step[0/1549], Loss: 5.4796, Perplexity: 239.74
# Epoch [2/5], Step[100/1549], Loss: 4.5379, Perplexity: 93.49
# Epoch [2/5], Step[200/1549], Loss: 4.6992, Perplexity: 109.86
# Epoch [2/5], Step[300/1549], Loss: 4.6814, Perplexity: 107.92
# Epoch [2/5], Step[400/1549], Loss: 4.5244, Perplexity: 92.24
# Epoch [2/5], Step[500/1549], Loss: 4.0623, Perplexity: 58.11
# Epoch [2/5], Step[600/1549], Loss: 4.4867, Perplexity: 88.83
# Epoch [2/5], Step[700/1549], Loss: 4.3748, Perplexity: 79.42
# Epoch [2/5], Step[800/1549], Loss: 4.4031, Perplexity: 81.70
# Epoch [2/5], Step[900/1549], Loss: 4.1903, Perplexity: 66.04
# Epoch [2/5], Step[1000/1549], Loss: 4.3217, Perplexity: 75.32
# Epoch [2/5], Step[1100/1549], Loss: 4.5375, Perplexity: 93.46
# Epoch [2/5], Step[1200/1549], Loss: 4.4335, Perplexity: 84.23
# Epoch [2/5], Step[1300/1549], Loss: 4.2364, Perplexity: 69.16
# Epoch [2/5], Step[1400/1549], Loss: 3.9425, Perplexity: 51.55
# Epoch [2/5], Step[1500/1549], Loss: 4.3372, Perplexity: 76.49
# Epoch [3/5], Step[0/1549], Loss: 4.5122, Perplexity: 91.12
# Epoch [3/5], Step[100/1549], Loss: 3.8603, Perplexity: 47.48
# Epoch [3/5], Step[200/1549], Loss: 4.0598, Perplexity: 57.96
# Epoch [3/5], Step[300/1549], Loss: 3.9470, Perplexity: 51.78
# Epoch [3/5], Step[400/1549], Loss: 3.8255, Perplexity: 45.85
# Epoch [3/5], Step[500/1549], Loss: 3.3657, Perplexity: 28.95
# Epoch [3/5], Step[600/1549], Loss: 3.9115, Perplexity: 49.98
# Epoch [3/5], Step[700/1549], Loss: 3.7248, Perplexity: 41.46
# Epoch [3/5], Step[800/1549], Loss: 3.7553, Perplexity: 42.75
# Epoch [3/5], Step[900/1549], Loss: 3.4723, Perplexity: 32.21
# Epoch [3/5], Step[1000/1549], Loss: 3.6307, Perplexity: 37.74
# Epoch [3/5], Step[1100/1549], Loss: 3.7915, Perplexity: 44.32
# Epoch [3/5], Step[1200/1549], Loss: 3.7932, Perplexity: 44.40
# Epoch [3/5], Step[1300/1549], Loss: 3.5629, Perplexity: 35.27
# Epoch [3/5], Step[1400/1549], Loss: 3.1819, Perplexity: 24.09
# Epoch [3/5], Step[1500/1549], Loss: 3.6548, Perplexity: 38.66
# Epoch [4/5], Step[0/1549], Loss: 3.6010, Perplexity: 36.64
# Epoch [4/5], Step[100/1549], Loss: 3.2818, Perplexity: 26.62
# Epoch [4/5], Step[200/1549], Loss: 3.5045, Perplexity: 33.26
# Epoch [4/5], Step[300/1549], Loss: 3.3694, Perplexity: 29.06
# Epoch [4/5], Step[400/1549], Loss: 3.3212, Perplexity: 27.69
# Epoch [4/5], Step[500/1549], Loss: 2.8655, Perplexity: 17.56
# Epoch [4/5], Step[600/1549], Loss: 3.4183, Perplexity: 30.52
# Epoch [4/5], Step[700/1549], Loss: 3.1726, Perplexity: 23.87
# Epoch [4/5], Step[800/1549], Loss: 3.2730, Perplexity: 26.39
# Epoch [4/5], Step[900/1549], Loss: 3.0062, Perplexity: 20.21
# Epoch [4/5], Step[1000/1549], Loss: 3.1397, Perplexity: 23.10
# Epoch [4/5], Step[1100/1549], Loss: 3.2308, Perplexity: 25.30
# Epoch [4/5], Step[1200/1549], Loss: 3.2633, Perplexity: 26.14
# Epoch [4/5], Step[1300/1549], Loss: 3.0292, Perplexity: 20.68
# Epoch [4/5], Step[1400/1549], Loss: 2.7435, Perplexity: 15.54
# Epoch [4/5], Step[1500/1549], Loss: 3.2230, Perplexity: 25.10
# Epoch [5/5], Step[0/1549], Loss: 3.0835, Perplexity: 21.84
# Epoch [5/5], Step[100/1549], Loss: 2.8890, Perplexity: 17.97
# Epoch [5/5], Step[200/1549], Loss: 3.1023, Perplexity: 22.25
# Epoch [5/5], Step[300/1549], Loss: 2.9993, Perplexity: 20.07
# Epoch [5/5], Step[400/1549], Loss: 2.9751, Perplexity: 19.59
# Epoch [5/5], Step[500/1549], Loss: 2.4992, Perplexity: 12.17
# Epoch [5/5], Step[600/1549], Loss: 3.0803, Perplexity: 21.76
# Epoch [5/5], Step[700/1549], Loss: 2.8793, Perplexity: 17.80
# Epoch [5/5], Step[800/1549], Loss: 2.9841, Perplexity: 19.77
# Epoch [5/5], Step[900/1549], Loss: 2.7052, Perplexity: 14.96
# Epoch [5/5], Step[1000/1549], Loss: 2.8747, Perplexity: 17.72
# Epoch [5/5], Step[1100/1549], Loss: 2.9010, Perplexity: 18.19
# Epoch [5/5], Step[1200/1549], Loss: 2.9770, Perplexity: 19.63
# Epoch [5/5], Step[1300/1549], Loss: 2.7111, Perplexity: 15.05
# Epoch [5/5], Step[1400/1549], Loss: 2.5328, Perplexity: 12.59
# Epoch [5/5], Step[1500/1549], Loss: 2.8575, Perplexity: 17.42
# Sampled [100/1000] words and save to sample.txt
# Sampled [200/1000] words and save to sample.txt
# Sampled [300/1000] words and save to sample.txt
# Sampled [400/1000] words and save to sample.txt
# Sampled [500/1000] words and save to sample.txt
# Sampled [600/1000] words and save to sample.txt
# Sampled [700/1000] words and save to sample.txt
# Sampled [800/1000] words and save to sample.txt
# Sampled [900/1000] words and save to sample.txt
# Sampled [1000/1000] words and save to sample.txt
