# %%
# !python main.py --content='png/content.png' --style='png/style.png'
# Out:
# Namespace(content='png/content.png', log_step=10, lr=0.003, max_size=400, sample_step=500, style='png/style.png', style_weight=100, total_step=2000)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /home/yang/.torch/models/vgg19-dcbb9e9d.pth
# 100%|████████████████████████| 574673361/574673361 [01:28<00:00, 6465110.31it/s]
# Step [10/2000], Content Loss: 5.1526, Style Loss: 24391.9727
# Step [20/2000], Content Loss: 12.9243, Style Loss: 22110.9023
# Step [30/2000], Content Loss: 20.2569, Style Loss: 19643.9180
# Step [40/2000], Content Loss: 26.9281, Style Loss: 17231.6582
# Step [50/2000], Content Loss: 33.0696, Style Loss: 14975.6895
# Step [60/2000], Content Loss: 38.6591, Style Loss: 12902.8037
# Step [70/2000], Content Loss: 43.7879, Style Loss: 11019.3760
# Step [80/2000], Content Loss: 48.5171, Style Loss: 9339.1387
# Step [90/2000], Content Loss: 52.8351, Style Loss: 7873.7886
# Step [100/2000], Content Loss: 56.7680, Style Loss: 6624.1128
# ...
